# %%
# coding: utf-8
# %matplotlib inline
import matplotlib.pyplot as plt

from evalys.jobset import JobSet

js = JobSet('jobs.csv')
print(js.df.describe())

js.df.hist()
js.gantt()
# Out:
#             jobID  submission_time  requested_number_of_processors  \
# count  300.000000              300                      300.000000
# mean   339.033333                0                        5.676667
# std    186.978829                0                        5.276197
# min      2.000000                0                        1.000000
# 25%    174.750000                0                        1.000000
# 50%    358.500000                0                        4.000000
# 75%    498.250000                0                        8.000000
# max    638.000000                0                       16.000000
#
#        requested_time  success  starting_time  execution_time   finish_time  \
# count      300.000000      300     300.000000      300.000000    300.000000
# mean   5097040.000000        1   17587.440207     8178.281432  25765.721639
# std    1052371.523979        0   12084.538122     7191.026062  13056.998314
# ...
